# %%
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:92c3ce89-f2e2-4680-8f68-887c72596f22

# %%
# !git clone https://github.com/paolito81/MaskArchitectureAnomaly_CourseProject.git
# %cd /content/MaskArchitectureAnomaly_CourseProject/eomt/
# %pip install -r requirements.txt

# %%
config_path = "/content/MaskArchitectureAnomaly_CourseProject/eomt/configs/dinov2/cityscapes/semantic/shared_eval.yaml"  # TODO: change to the config file
data_path = "/content/drive/MyDrive/dataset_city_scapes/cityscapes"
local_ckpt_path = "/content/drive/MyDrive/CourseProjectAnomaly/eomt_cityscapes.bin"

# %%
# !python3 main.py validate \
  -c {config_path} \
  --model.network.masked_attn_enabled False \
  --trainer.devices 1 \
  --data.batch_size 1 \
  --data.path {data_path} \
  --model.ckpt_path {local_ckpt_path}
